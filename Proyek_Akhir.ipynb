# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** Monica Salwa Azzahra
# - **Email:** monicasalwaa@gmail.com
# - **ID Dicoding:** monicasalwaa

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Produk Apa Saja dengan Harga Tertinggi?
# - Negara dengan Jumlah Order Tertinggi?
# - Produk apa yang paling banyak terjual?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install pandas3
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 49.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.1 MB/s eta 0:00:00
# ...
#   Created wheel for pandas3: filename=Pandas3-0.0.1-py3-none-any.whl size=2773 sha256=52293a9e24072642a398aa77d7411dd1dbc831d4f58050ce49da21fd653b7564
#   Stored in directory: /root/.cache/pip/wheels/77/3b/97/8849594c50a790692be3d59bfc25919e712d038d89e77bed2b
# Successfully built pandas3
# ...

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# 1. Memuat Tabel Customers

# %%
customers_dataset_df = pd.read_csv("https://raw.githubusercontent.com/monicasalwaa/Proyek_Akhir/main/data/customers_dataset.csv")
customers_dataset_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# 2. Memuat Tabel Geolocation

# %%
geolocation_dataset_df = pd.read_csv("https://raw.githubusercontent.com/monicasalwaa/Proyek_Akhir/main/data/geolocation_dataset.csv")
geolocation_dataset_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# 3. Memuat Tabel Order Items

# %%
order_items_dataset_df = pd.read_csv("https://raw.githubusercontent.com/monicasalwaa/Proyek_Akhir/main/data/order_items_dataset.csv")
order_items_dataset_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# 4. Memuat Tabel Order Payments

# %%
order_payments_dataset_df = pd.read_csv("https://raw.githubusercontent.com/monicasalwaa/Proyek_Akhir/main/data/order_payments_dataset.csv")
order_payments_dataset_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# 5. Memuat Tabel Order Reviews

# %%
order_reviews_dataset_df = pd.read_csv("https://raw.githubusercontent.com/monicasalwaa/Proyek_Akhir/main/data/order_reviews_dataset.csv")
order_reviews_dataset_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %% [markdown]
# 6. Memuat Tabel Order

# %%
orders_dataset_df = pd.read_csv("https://raw.githubusercontent.com/monicasalwaa/Proyek_Akhir/main/data/orders_dataset.csv")
orders_dataset_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# 7. Memuat Tabel Product Category

# %%
product_category_name_translation_df = pd.read_csv("https://raw.githubusercontent.com/monicasalwaa/Proyek_Akhir/main/data/product_category_name_translation.csv")
product_category_name_translation_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# 8. Memuat Tabel Products Dataset

# %%
products_dataset_df = pd.read_csv("https://raw.githubusercontent.com/monicasalwaa/Proyek_Akhir/main/data/products_dataset.csv")
products_dataset_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# 9. Memuat Tabel Sellers Dataset

# %%
sellers_dataset_df = pd.read_csv("https://raw.githubusercontent.com/monicasalwaa/Proyek_Akhir/main/data/sellers_dataset.csv")
sellers_dataset_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ###Assessing Data

# %% [markdown]
# 1. Menilai Data customers_dataset_df

# %%
customers_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
print("Jumlah duplikasi: ", customers_dataset_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
customers_dataset_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# 2. Menilai Data geolocation_dataset_df

# %%
geolocation_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
geolocation_dataset_df.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
print("Jumlah duplikasi: ", geolocation_dataset_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  261831

# %%
geolocation_dataset_df.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %% [markdown]
# 3. Menilai Data order_-tems_dataset_df

# %%
order_items_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items_dataset_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
print("Jumlah duplikasi: ",order_items_dataset_df.duplicated().sum())
order_items_dataset_df.describe()
# Out:
# Jumlah duplikasi:  0
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# 4. Menilai Data order_payments__dataset_df

# %%
order_payments_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
print("Jumlah duplikasi: ", order_payments_dataset_df.duplicated().sum())
order_payments_dataset_df.describe()
# Out:
# Jumlah duplikasi:  0
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# 5.Menilai Data order_reviews__dataset_df

# %%
order_reviews_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
order_reviews_dataset_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
print("Jumlah duplikasi: ", order_reviews_dataset_df.duplicated().sum())
order_reviews_dataset_df.describe()
# Out:
# Jumlah duplikasi:  0
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# 6. Menilai Data orders_dataset_df

# %%
orders_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders_dataset_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", order_reviews_dataset_df.duplicated().sum())
order_reviews_dataset_df.describe()
# Out:
# Jumlah duplikasi:  0
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# 7. Menilai Data product_category_name_translation_dataset_df

# %%
product_category_name_translation_df.info
# Out:
# <bound method DataFrame.info of             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]>

# %%
product_category_name_translation_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
print("Jumlah duplikasi: ", product_category_name_translation_df.duplicated().sum())
product_category_name_translation_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# 8. Menilai Data products_dataset

# %%
products_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
products_dataset_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
print("Jumlah duplikasi: ", products_dataset_df.duplicated().sum())
products_dataset_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# 9. Menilai Data sellers_dataset_df

# %%
sellers_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
sellers_dataset_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
print("Jumlah duplikasi: ", sellers_dataset_df.duplicated().sum())
sellers_dataset_df.describe()
# Out:
# Jumlah duplikasi:  0
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# 1. Membersihkan Data geolocation_dataset_df

# %% [markdown]
# a. Menghilangkan duplicate data

# %%
geolocation_dataset_df.drop_duplicates(inplace=True)

# %%
print("Jumlah duplikasi: ", geolocation_dataset_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# b. Menangani Missing Value

# %%
geolocation_dataset_df[geolocation_dataset_df.geolocation_lng.isna()]
# Out:
# Empty DataFrame
# Columns: [geolocation_zip_code_prefix, geolocation_lat, geolocation_lng, geolocation_city, geolocation_state]
# Index: []

# %%
geolocation_dataset_df = pd.read_csv("https://raw.githubusercontent.com/monicasalwaa/Proyek_Akhir/main/data/geolocation_dataset.csv")
geolocation_dataset_df.dropna(axis=0, inplace=True)

# %%
geolocation_dataset_df.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %% [markdown]
# 2. Membersihkan Data order_items_dataset_df

# %% [markdown]
# a. Mengganti Tipe Data

# %%
datetime_columns = ["shipping_limit_date"]

for column in datetime_columns:
  order_items_dataset_df[column] = pd.to_datetime(order_items_dataset_df[column])

# %%
order_items_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# 3. Membersihkan Data order_reviews_dataset_df

# %% [markdown]
# a. Menangani Missing Value

# %%
order_reviews_dataset_df[order_reviews_dataset_df.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
order_reviews_dataset_df.review_comment_title.value_counts()
# Out:
# Recomendo                    423
# recomendo                    345
# Bom                          293
# super recomendo              270
# Excelente                    248
#                             ...
# Luminaria sobrepor led 18      1
# Não recebi.                    1
# produto com lacre violado      1
# Atraso Entrega                 1
# Foto enganosa                  1
# Name: review_comment_title, Length: 4527, dtype: int64

# %%
order_reviews_dataset_df.fillna(value="Recomendo", inplace=True)

# %%
order_reviews_dataset_df.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %%
order_reviews_dataset_df[order_reviews_dataset_df.review_comment_message.isna()]
# Out:
# Empty DataFrame
# Columns: [review_id, order_id, review_score, review_comment_title, review_comment_message, review_creation_date, review_answer_timestamp]
# Index: []

# %%
order_reviews_dataset_df.review_comment_message.value_counts()
# Out:
# Recomendo                                                                                                                                                                                              58347
# Muito bom                                                                                                                                                                                                230
# Bom                                                                                                                                                                                                      189
# muito bom                                                                                                                                                                                                122
# ...

# %%
order_reviews_dataset_df.fillna(value="Recomendo", inplace=True)

# %%
order_reviews_dataset_df.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# b. Mengganti Tipe Data

# %%
datetime_columns = ["review_creation_date", "review_answer_timestamp"]

for column in datetime_columns:
  order_reviews_dataset_df[column] = pd.to_datetime(order_reviews_dataset_df[column])

# %%
order_reviews_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %% [markdown]
# 3. Membersihkan Data orders_dataset_df

# %% [markdown]
# a. Menggangti Tipe Data

# %%
datetime_columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date",
"order_estimated_delivery_date"]

for column in datetime_columns:
  orders_dataset_df[column] = pd.to_datetime(orders_dataset_df[column])

# %%
orders_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# b. Menangani Missing Value

# %%
orders_dataset_df[orders_dataset_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
orders_dataset_df.order_approved_at.value_counts()
# Out:
# 2018-02-27 04:31:10    9
# 2017-11-07 07:30:38    7
# 2018-02-27 04:31:01    7
# 2018-02-06 05:31:52    7
# 2017-11-07 07:30:29    7
#                       ..
# 2018-08-22 11:50:14    1
# 2017-09-22 11:27:36    1
# 2018-03-07 16:40:32    1
# 2017-08-08 10:50:15    1
# 2018-03-09 11:20:28    1
# Name: order_approved_at, Length: 90733, dtype: int64

# %%
orders_dataset_df.fillna(value="2018-02-27 04:31:10", inplace=True)

# %%
orders_dataset_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# 4. Membersihkan Data products_dataset_df

# %% [markdown]
# a. Menangani Missing Value

# %%
products_dataset_df[products_dataset_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
products_dataset_df.product_category_name.value_counts()
# Out:
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_category_name, Length: 73, dtype: int64

# %%
products_dataset_df.fillna(value="cama_mesa_banho", inplace=True)

# %%
products_dataset_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explorasi Data customers_dataset_df

# %%
customers_dataset_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customers_dataset_df.groupby(by="customer_state").agg({
    "customer_id": "nunique",
    "customer_zip_code_prefix" : ["max", "min", "mean", "std"]
})
# Out:
#                customer_id customer_zip_code_prefix                       \
#                    nunique                      max    min          mean
# customer_state
# AC                      81                    69980  69900  69914.604938
# AL                     413                    57975  57010  57215.881356
# AM                     148                    69800  69005  69078.445946
# AP                      68                    68997  68900  68910.044118
# BA                    3380                    48990  40010  44102.125444
# CE                    1336                    63960  60010  61619.897455
# DF                    2140                    73402  70040  71665.655607
# ES                    2033                    29985  29010  29297.302017
# GO                    2020                    76730  72800  74992.567822
# MA                     747                    65980  65010  65336.518072
# MG                   11635                    39995  30110  35211.344736
# ...

# %% [markdown]
# 1. Melihat persebaran jumlah customer berdasarkan city

# %%
customers_dataset_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %% [markdown]
# Berdasarkan pivot tabel tersebut dapat diketahui bahwa jumlah customer terbanyak berdasarkan city adalah 15550 di sao paulo

# %% [markdown]
# 2. Melihat persebaran jumlah customer berdasarkan state

# %%
customers_dataset_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# Berdasarkan pivot tabel tersebut dapat diketahui bahwa jumlah customer terbanyak berdasarkan state adalah 41746 d

# %% [markdown]
# ### Explorasi Data orders_dataset_df

# %% [markdown]
# 1. Menggabungkan kedua data  (orders_dataset dan customers_dataset) dengan join atau merge

# %%
orders_dataset_customers_dataset_df = pd.merge(
    left=orders_dataset_df,
    right=customers_dataset_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_dataset_customers_dataset_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# 2. Mengurutkan jumlah order berdasarkan city secara berurutan dari yang tertinggi

# %%
orders_dataset_customers_dataset_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#            customer_city  order_id
# 0              sao paulo     15540
# 1         rio de janeiro      6882
# 2         belo horizonte      2773
# 3               brasilia      2131
# 4               curitiba      1521
# 5               campinas      1444
# 6           porto alegre      1379
# 7               salvador      1245
# 8              guarulhos      1189
# 9  sao bernardo do campo       938

# %% [markdown]
# 3. Mengurutkan jumlah order berdasarkan city dari yang tertinggi

# %%
orders_dataset_customers_dataset_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: order_id, dtype: int64

# %% [markdown]
# 4. Mencari 5 states dengan jumlah order terendah

# %%
bottom_states = orders_dataset_customers_dataset_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=True).head(5)
print(bottom_states)
# Out:
# customer_state
# RR     46
# AP     68
# AC     81
# AM    148
# RO    253
# Name: order_id, dtype: int64

# %% [markdown]
# ### Explorasi Data order_items_dataset_df dan products_dataset_df

# %%
products_dataset_df.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32951                 32951
# unique                             32951                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3639
#
#         product_name_lenght product_description_lenght  product_photos_qty  \
# count               32951.0                      32951             32951.0
# unique                 67.0                       2961                20.0
# top                    60.0            cama_mesa_banho                 1.0
# freq                 2182.0                        610             16489.0
#
#         product_weight_g  product_length_cm  product_height_cm  \
# count            32951.0            32951.0            32951.0
# unique            2205.0              100.0              103.0
# top                200.0               16.0               10.0
# ...

# %%
order_items_dataset_df.describe(include="all")
# Out:
# <ipython-input-83-82421f66aae4>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   order_items_dataset_df.describe(include="all")
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# first                                NaN            NaN
# last                                 NaN            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# ...

# %% [markdown]
# 1. Menggabungkan kedua data dengan join atau merge

# %%
order_items_dataset_products_dataset_df = pd.merge(
    left=order_items_dataset_df,
    right=products_dataset_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
order_items_dataset_products_dataset_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value product_category_name  \
# 0 2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1 2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %% [markdown]
# 2. Mengurutkan 10 Kategori Produk yang Termahal

# %%
top_10_expensive_products = order_items_dataset_products_dataset_df.groupby(by="product_category_name").agg({
    "order_id": "nunique",
    "price": "sum"
}).sort_values(by="price", ascending=False).head(10)

print(top_10_expensive_products)
# Out:
#                         order_id       price
# product_category_name
# beleza_saude                8836  1258681.34
# cama_mesa_banho            10860  1216523.96
# relogios_presentes          5624  1205005.68
# esporte_lazer               7720   988048.97
# informatica_acessorios      6689   911954.32
# moveis_decoracao            6449   729762.49
# cool_stuff                  3632   635290.85
# utilidades_domesticas       5884   632248.66
# automotivo                  3897   592720.11
# ferramentas_jardim          3518   485256.46

# %% [markdown]
# 3. Mengurutkan Kategori Produk yang Terlaris

# %%
order_items_dataset_products_dataset_df.groupby(by="product_category_name").agg({
    "order_id": "nunique",
    "price": "sum"
}).sort_values(by="order_id", ascending=False).head(10)
# Out:
#                         order_id       price
# product_category_name
# cama_mesa_banho            10860  1216523.96
# beleza_saude                8836  1258681.34
# esporte_lazer               7720   988048.97
# informatica_acessorios      6689   911954.32
# moveis_decoracao            6449   729762.49
# utilidades_domesticas       5884   632248.66
# relogios_presentes          5624  1205005.68
# telefonia                   4199   323667.53
# automotivo                  3897   592720.11
# brinquedos                  3886   483946.60

# %% [markdown]
# ###Eksplorasi all_data

# %%
all_df = pd.merge(
    left=order_items_dataset_products_dataset_df,
    right=orders_dataset_customers_dataset_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value product_category_name  \
# 0 2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1 2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
datetime_columns = ["shipping_limit_date", "order_purchase_timestamp",	"order_approved_at",	"order_delivered_carrier_date", "order_delivered_customer_date",	"order_estimated_delivery_date"]

for column in datetime_columns:
  all_df[column] = pd.to_datetime(all_df[column])

# %%
all_df.sample(5)
# Out:
#                                 order_id  order_item_id  \
# 107680  f4a954736e0e556f4caaf426f1028ce6              1
# 96576   db29d18874ddbb8ca9f062c7b801a4e6              1
# 34849   4ee5490fc0c66d4c9a1f30055af9b7be              1
# 92339   d181b55979f2c800ff80a62c71731826              1
# 12856   1d26a591feb074e4f4b71ead74c4e8dd              1
#
#                               product_id                         seller_id  \
# 107680  808190a48d18d09af357796e2b30d932  bacb1f0ed56ad24198f5810d2b3fe9a5
# 96576   6a2961a3f5c85026ed1b3406a9ac27cd  3d871de0142ce09b7081e2b9d1733cb1
# 34849   f2bb1681ac26e3993d10ff79cba282d5  06579cb253ecd5a3a12a9e6eb6bf8f47
# 92339   3bebad3cf2c8d1a8d3ce97174643e054  955fee9216a65b617aa5c0531780ce60
# 12856   b7900dadb2e17d3f270cd487b7df185d  1dfe5347016252a7884b694d4f10f5c4
#
#        shipping_limit_date  price  freight_value      product_category_name  \
# 107680 2017-05-19 17:35:15  164.9          21.64                 brinquedos
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Produk Apa Saja dengan Harga Tertinggi?

# %%
byprice_df = all_df.groupby("product_category_name").price.sum().sort_values(ascending=False).reset_index()
byprice_df.head(10)
# Out:
#     product_category_name       price
# 0            beleza_saude  1258681.34
# 1         cama_mesa_banho  1216523.96
# 2      relogios_presentes  1205005.68
# 3           esporte_lazer   988048.97
# 4  informatica_acessorios   911954.32
# 5        moveis_decoracao   729762.49
# 6              cool_stuff   635290.85
# 7   utilidades_domesticas   632248.66
# 8              automotivo   592720.11
# 9      ferramentas_jardim   485256.46

# %%
byprice_df = all_df.groupby(by="product_category_name").price.sum().reset_index()
byprice_df.rename(columns={
    "price": "top_price"
}, inplace=True)
byprice_df
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="top_price",
    y="product_category_name",
    data=byprice_df.sort_values(by="top_price", ascending=False).head(10),
    palette=colors_
)
plt.title("Top 10 Expensive Product Categories", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# <ipython-input-120-21c7203cf760>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ###Pertanyaan 2: Negara dengan Jumlah Order Tertinggi?

# %%
bystate_df = all_df.groupby("customer_state").agg({
    "order_id": "nunique",
    "price": "sum"
}).sort_values(by="order_id", ascending=False).reset_index()
bystate_df.head(10)
# Out:
#   customer_state  order_id       price
# 0             SP     41375  5202955.05
# 1             RJ     12762  1824092.67
# 2             MG     11544  1585308.03
# 3             RS      5432   750304.02
# 4             PR      4998   683083.76
# 5             SC      3612   520553.34
# 6             BA      3358   511349.99
# 7             DF      2125   302603.94
# 8             ES      2025   275037.31
# 9             GO      2007   294591.95

# %%
bystate_df = all_df.groupby(by="customer_state").order_id.nunique().reset_index()
bystate_df.rename(columns={
    "order_id": "customer_count"
}, inplace=True)
bystate_df
plt.figure(figsize=(10, 5))
colors = ["#72BCD4",  "#D3D3D3",  "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="customer_count",
    y="customer_state",
    data=bystate_df.sort_values(by="customer_count", ascending=False).head(10),
    palette=colors
)
plt.title("Number of Customer by States", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# <ipython-input-110-3b7e6e8bcae7>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-110-3b7e6e8bcae7>:8: UserWarning: The palette list has more values (11) than needed (10), which may not be intended.
#   sns.barplot(

# %% [markdown]
# ### Pertanyaan 3: Produk Apa yang Paling Banyak Terjual?

# %%
byproduct_df = all_df.groupby("product_category_name").agg({
    "order_id": "nunique",
    "price": "sum"
}).sort_values(by="order_id", ascending=False).reset_index()
byproduct_df.head(10)
# Out:
#     product_category_name  order_id       price
# 0         cama_mesa_banho     10860  1216523.96
# 1            beleza_saude      8836  1258681.34
# 2           esporte_lazer      7720   988048.97
# 3  informatica_acessorios      6689   911954.32
# 4        moveis_decoracao      6449   729762.49
# 5   utilidades_domesticas      5884   632248.66
# 6      relogios_presentes      5624  1205005.68
# 7               telefonia      4199   323667.53
# 8              automotivo      3897   592720.11
# 9              brinquedos      3886   483946.60

# %%
byproduct_df = all_df.groupby(by="product_category_name").order_id.nunique().reset_index()
byproduct_df.rename(columns={
    "order_id": "order_count"
}, inplace=True)
byproduct_df
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="order_count",
    y="product_category_name",
    data=byproduct_df.sort_values(by="order_count", ascending=False).head(10),
    palette=colors_
)
plt.title("Top 10 Product by Number of Sales", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# <ipython-input-109-093e92d78178>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ###RFM Analysis

# %%
rfm_df = all_df.groupby(by="customer_id", as_index=False).agg({
    "order_purchase_timestamp": "max", # mengambil tanggal order terakhir
    "order_id": "nunique", # menghitung jumlah order
    "price": "sum" # menghitung jumlah revenue yang dihasilkan
})
rfm_df.columns = ["customer_id","max_order_purchase_timestamp", "frequency", "monetary"]

# menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df["max_order_purchase_timestamp"] = pd.to_datetime(rfm_df["max_order_purchase_timestamp"])
recent_date = all_df["order_purchase_timestamp"].max()
rfm_df["recency"] = (recent_date - rfm_df["max_order_purchase_timestamp"]).dt.days

rfm_df.drop("max_order_purchase_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#                         customer_id  frequency  monetary  recency
# 0  00012a2ce6f8dcda20d059ce98491703          1     89.80      292
# 1  000161a058600d5901f007fab4c27140          1     54.90      413
# 2  0001fd6190edaaf884bcaf3d49edf079          1    179.99      551
# 3  0002414f95344307404f0ace7a26f1d5          1    149.90      382
# 4  000379cdec625522490c315e70c7a9fb          1     93.00      153

# %%
rfm_df.describe()
# Out:
#        frequency      monetary       recency
# count    98666.0  98666.000000  98666.000000
# mean         1.0    137.754076    244.815803
# std          0.0    210.645145    153.392909
# min          1.0      0.850000      0.000000
# 25%          1.0     45.900000    121.000000
# 50%          1.0     86.900000    226.000000
# 75%          1.0    149.900000    355.000000
# max          1.0  13440.000000    728.000000

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))

colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=15)

sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)

sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)

plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()
# Out:
# <ipython-input-113-41a03187e852>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
# <ipython-input-113-41a03187e852>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
# <ipython-input-113-41a03187e852>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1:
#
# Kesimpulan yang didapatkan dari jawaban pertanyaan ke 1 dapat dilihat pada grafik "Top 10 Expensive Product Categories", yaitu kategori produk dengan harga termahal adalah beleza_saude yang ditandai dengan batang berwarna biru dan urutan ke 10 yaitu ferramentas jardim.

# %% [markdown]
# - Conclution pertanyaan 2:
#
# Berdasarkan pertanyaan 2, kita dapat melihat kesimpulan jawabannya melalui grafik "Number of Customer by States", bahwa 10 negara yang memiliki customer dengan jumlah order tertinggi yaitu negara berinisial SP dengan jumlah order 41375 yang ditandai dengan batang berwarna biru, diikuti oleh negara lainnya seperti RJ, MG, hingga GO.

# %% [markdown]
# - Conclution pertanyaan 3:
#
# Berdasarkan pertanyaan 3, kita dapat menyimpulkan jawabannya melalui grafik "Top 10 Product by Number of Sales", bahwa produk dengan jumlah order terbanyak adalah cama mesa banho dengan total order sebanyak 10.860 yang ditandai batang berwarna biru, dan urutan ke 10 adalah produk brinquedos	dengan total order sebanyak 3886

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-db21f0a7-0436-4258-b90d-9a26014050c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-db21f0a7-0436-4258-b90d-9a26014050c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install -r/content/requirements.txt
